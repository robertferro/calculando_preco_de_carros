# %% [markdown]
# ## Objetivo:
#
#  - Coletar dados de diferentes modelos de carros do mercado livre.
#  - criar um arquivo csv "carros.csv".

# %% [markdown]
# ## 1- Web Scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep

# %%
# url = 'https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/'
url = 'https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/volkswagem_Desde_289'
# url ='https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/fiat/_Desde_49'
c = requests.get(url).content

# %%
soup = BeautifulSoup(c)

# %% [markdown]
# ## Criando listas com caraterísticas do modelo.

# %% [markdown]
#  - Preço

# %%
lista_preco_tags = soup.find_all('span', {'class':'price-tag-fraction'})
lista_preco = [info.text for info in lista_preco_tags ]
lista_preco[:5]
# Out:
# ['68.900', '71.890', '33.990', '194.949', '36.890']

# %%
len(lista_preco)
# Out:
# 48

# %% [markdown]
#  - Quilometragem

# %%
lista_km_tags = soup.find_all('li', {'class':'ui-search-card-attributes__attribute'})
lista_km = [info.text for info in lista_km_tags ]
lista_km = lista_km[1::2]
lista_km[:5]
# Out:
# ['77.500 Km', '52.900 Km', '48.000 Km', '31.865 Km', '103.250 Km']

# %%
len(lista_km)
# Out:
# 48

# %% [markdown]
#  - Ano

# %%
lista_ano_tags = soup.find_all('li', {'class':'ui-search-card-attributes__attribute'})
lista_ano = [info.text for info in lista_ano_tags ]
lista_ano = lista_ano[::2]
lista_ano[:5]
# Out:
# ['2014', '2019', '2012', '2019', '2015']

# %%
len(lista_ano)
# Out:
# 48

# %% [markdown]
#  - Características (marca, modelo, câmbio)

# %%
lista_car_tags = soup.find_all('h2', {'class':'ui-search-item__title ui-search-item__group__element'})
lista_car = [info.text for info in lista_car_tags ]
lista_car[:10]
# Out:
# ['Volkswagen Golf 1.4 Tsi Highline 5p Automática',
#  'Volkswagen Polo Polo Highline 200',
#  'Volkswagen Voyage 1.6 Vht Comfortline Total Flex 4p',
#  'Volkswagen Tiguan Allspace 2.0 R-line 350 Tsi 4motion 5p',
#  'Volkswagen Fox 1.0 12v Bluemotion Total Flex 5p',
#  'Volkswagen Fox 1.0 Mi Trend 8v Flex 4p Manual',
#  'Volkswagen Polo 1.6 16v Msi 5p',
#  'Volkswagen Jetta 2.5 170cv',
#  'Volkswagen Fox 1.6 Xtreme Total Flex 5p',
#  'Volkswagen Gol 1.0 12v Mpi Totalflex 4p Manual']

# %%
len(lista_car)
# Out:
# 48

# %% [markdown]
# ## Criando uma lista com os endereços

# %%
lista_pag = []
for i in range(1,1537):
    num_1 ='_Desde_'
    num_2 = i
    num = '{}{}'.format(num_1,num_2)
    lista_pag.append(num)


lista_pag_1 = lista_pag[::48]
lista_pag_1[0] = ''

# %%
modelos = ['chevrolet/agile/','chevrolet/astra/','chevrolet/celta/','chevrolet/classic/',
           'chevrolet/cobalt/','chevrolet/corsa/','chevrolet/corsa-classic/',
           'chevrolet/corsa-sedan/','chevrolet/cruze/','chevrolet/joy/','chevrolet/montana/',
           'chevrolet/onix/','chevrolet/prisma/','chevrolet/S10/','chevrolet/spin/','chevrolet/tracker/','chevrolet/vectra/',
           'volkswagen/amarok/','volkswagen/crossfox/','volkswagen/fox/','volkswagen/fusca/','volkswagen/gol/',
           'volkswagen/golf/','volkswagen/jetta/','volkswagen/kombi/','volkswagen/parati/','volkswagen/polo/',
           'volkswagen/polo-Sedan/','volkswagen/saveiro/','volkswagen/spacefox/','volkswagen/T-Cross/',
           'volkswagen/virtus/','volkswagen/voyage/',
           'fiat/argo/','fiat/bravo/','fiat/cronos/','fiat/doblo/',
           'fiat/fiorino/','fiat/freemont/','fiat/grand-siena/','fiat/idea/','fiat/linea/',
           'fiat/mobi/','fiat/palio/','fiat/Palio-Weekend/','fiat/punto/',
           'fiat/siena/','fiat/stilo/','fiat/strada/','fiat/toro/','fiat/uno/',
           'ford/ecosport/','ford/escort/','ford/fiesta/','ford/fiesta-sedan/',
           'ford/focus/','ford/focus-sedan/','ford/fusion/','ford/Ka/','ford/ranger/',
           'hyundai/creta/','hyundai/HB20/','hyundai/HB20S/',
           'hyundai/I30/','hyundai/IX35/','hyundai/Santa-Fe/','hyundai/tucson/',
           'renault/captur/','renault/clio/','renault/duster/','renault/Duster-Oroch/',
           'renault/fluence/','renault/kwid/','renault/logan/','renault/Sandero/',
           'toyota/corolla/','toyota/etios/','toyota/hilux/','toyota/RAV4/','toyota/SW4/','toyota/yaris/',
           'honda/city/','honda/civic/','honda/CR-V/','honda/fit/','honda/HR-V/','honda/WR-V/',
           'peugeot/2008/','peugeot/206/','peugeot/207/','peugeot/207-Passion/','peugeot/208/','peugeot/3008/',
           'peugeot/307/','peugeot/308/','peugeot/408/',
           'citroen/aircross/','citroen/C3/','citroen/C3-Picasso/','citroen/C4/','citroen/C4-Cactus/',
           'citroen/C4-Lounge/','citroen/C4-Pallas/','citroen/C4-Picasso/','citroen/Xsara-Picasso/',
           'kia/cerato/','kia/picanto/','kia/soul/','kia/sportage/',
           'nissan/frontier/','nissan/kicks/','nissan/livina/','nissan/march/','nissan/sentra/','nissan/tiida/','nissan/versa/',
           'mitsubishi/ASX/','mitsubishi/L200/','mitsubishi/Lancer/','mitsubishi/Outlander/',
           'mitsubishi/pajero/','mitsubishi/Pajero-Full/','mitsubishi/Pajero-Sport/','mitsubishi/Pajero-TR4/',

            ]

# %%
URL = 'https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros'

paginas = lista_pag_1[0:2]

# %%
def scrap(url):
    c = requests.get(url).content
    soup = BeautifulSoup(c)
    lista_preco_tags = soup.find_all('span', {'class':'price-tag-fraction'})
    lista_preco = [info.text for info in lista_preco_tags ]
    lista_preco = lista_preco[:48]
    lista_km_tags = soup.find_all('li', {'class':'ui-search-card-attributes__attribute'})
    lista_km = [info.text for info in lista_km_tags ]
    lista_km = lista_km[1::2]
    lista_ano_tags = soup.find_all('li', {'class':'ui-search-card-attributes__attribute'})
    lista_ano = [info.text for info in lista_ano_tags ]
    lista_ano = lista_ano[::2]
    lista_car_tags = soup.find_all('h2', {'class':'ui-search-item__title ui-search-item__group__element'})
    lista_car = [info.text for info in lista_car_tags ]
    df = convert_df(modelos,lista_preco, lista_km, lista_ano, lista_car )
    return df


def convert_df(modelos, lista_preco, lista_km, lista_ano, lista_car ):
    modelos_lista = [modelo]*len(lista_preco)
    data = {'modelo':modelos_lista,
            'preco':lista_preco,
            'quilometragem':lista_km,
            'ano':lista_ano,
            'infomacoes': lista_car,
            
            }
    df = pd.DataFrame(data)
    return df

# %%
lista_dfs = []
for modelo in modelos:
    for pag in paginas:
        url ='https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros/{}{}'.format(modelo,pag)
        print(url)
        df=scrap(url)
        lista_dfs.append(df)
        sleep(1)
# Out:
# https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros/chevrolet/agile/
# https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros/chevrolet/agile/_Desde_49
# https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros/chevrolet/astra/
# https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros/chevrolet/astra/_Desde_49
# https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros/chevrolet/celta/
# https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros/chevrolet/celta/_Desde_49
# https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros/chevrolet/classic/
# https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros/chevrolet/classic/_Desde_49
# https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros/chevrolet/cobalt/
# https://lista.mercadolivre.com.br/veiculos/carros-caminhonetes/carros/chevrolet/cobalt/_Desde_49
# ...

# %% [markdown]
#  - Criando o df com o resultado da pesquisa

# %%
df = pd.concat(lista_dfs)

# %%
pd.set_option('display.max_rows', 501)
df.head(501)
# Out:
#                 modelo       preco quilometragem   ano  \
# 0     chevrolet/agile/      25.990     91.000 Km  2011
# 1     chevrolet/agile/      23.499     78.400 Km  2011
# 2     chevrolet/agile/      28.900    123.915 Km  2013
# 3     chevrolet/agile/      28.000     91.000 Km  2013
# 4     chevrolet/agile/      31.990    106.863 Km  2014
# 5     chevrolet/agile/      29.900     58.000 Km  2012
# 6     chevrolet/agile/      26.990     97.000 Km  2010
# 7     chevrolet/agile/      28.999     97.000 Km  2012
# 8     chevrolet/agile/      25.900    132.000 Km  2012
# 9     chevrolet/agile/      26.900    100.000 Km  2010
# 10    chevrolet/agile/      27.900    108.000 Km  2013
# 11    chevrolet/agile/      32.900     52.341 Km  2012
# 12    chevrolet/agile/      22.320          0 Km  2011
# 13    chevrolet/agile/      36.900     90.000 Km  2014
# 14    chevrolet/agile/      26.990    180.000 Km  2010
# 15    chevrolet/agile/      31.900     92.000 Km  2014
# ...

# %%
df.shape
# Out:
# (11904, 5)

# %% [markdown]
#  - Como podeser visto acima , a numeração vai sempre de 0 a 48, logo teremos que atribuir uma numeração única ao índice.

# %%
df = df.reset_index()

# %%
df = df.drop('index', axis =1)

# %% [markdown]
#  Agora a numeração do índice segue uma ordenação única.

# %%
df.head()
# Out:
#              modelo   preco quilometragem   ano  \
# 0  chevrolet/agile/  25.990     91.000 Km  2011
# 1  chevrolet/agile/  23.499     78.400 Km  2011
# 2  chevrolet/agile/  28.900    123.915 Km  2013
# 3  chevrolet/agile/  28.000     91.000 Km  2013
# 4  chevrolet/agile/  31.990    106.863 Km  2014
#
#                                         infomacoes
# 0                        Chevrolet Agile 1.4 Lt 5p
# 1                       Chevrolet Agile 1.4 Ltz 5p
# 2                       Chevrolet Agile 1.4 Ltz 5p
# 3                        Chevrolet Agile 1.4 Lt 5p
# 4  Chevrolet Agile Agile 1.4 Ltz 8v Flex 4p Manual

# %% [markdown]
#  - Salvando o arquivo em formato csv para ser manipulado

# %%
df.to_csv('carros_populares.csv', index =False , encoding = 'utf-8')

# %%
dados = pd.read_csv('carros_populares.csv')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11904 entries, 0 to 11903
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   modelo         11904 non-null  object
#  1   preco          11904 non-null  object
#  2   quilometragem  11904 non-null  object
#  3   ano            11904 non-null  int64
#  4   infomacoes     11904 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 465.1+ KB

# %%
dados.head()
# Out:
#              modelo   preco quilometragem   ano  \
# 0  chevrolet/agile/  25.990     91.000 Km  2011
# 1  chevrolet/agile/  23.499     78.400 Km  2011
# 2  chevrolet/agile/  28.900    123.915 Km  2013
# 3  chevrolet/agile/  28.000     91.000 Km  2013
# 4  chevrolet/agile/  31.990    106.863 Km  2014
#
#                                         infomacoes
# 0                        Chevrolet Agile 1.4 Lt 5p
# 1                       Chevrolet Agile 1.4 Ltz 5p
# 2                       Chevrolet Agile 1.4 Ltz 5p
# 3                        Chevrolet Agile 1.4 Lt 5p
# 4  Chevrolet Agile Agile 1.4 Ltz 8v Flex 4p Manual

# %%
dados.shape
# Out:
# (11904, 5)
